# %% [markdown]
# # Practical10: Visualization
#
# **Name:** TANVI ASHOK KADGE
# **Roll No:** TCS2526025

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('train.csv')
plt.figure(figsize=(10,5))
plt.subplot(1, 2, 1)
sns.histplot(df['Fare'], kde=True)
plt.subplot(1, 2, 2)
sns.boxplot(y=df['Age'])
plt.show()
