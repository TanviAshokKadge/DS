# %% [markdown]
# # Practical 3: MTCARS EDA
#
# **Name:** TANVI ASHOK KADGE
#
# **Roll No:** SCS2425037

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("mtcars.csv")
df.head()

# %%
df.info()
df.describe()

# %%
sns.countplot(x="am", hue="cyl", data=df)
plt.show()

# %% [markdown]
# ## Conclusion
# Explored car dataset.
