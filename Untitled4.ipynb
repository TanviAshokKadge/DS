# %% [markdown]
# <a href="https://colab.research.google.com/github/TanviAshokKadge/DS/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
It seems like I can’t do more advanced data analysis right now. Please try again later.

But don’t worry—I’ll still help you get your **MongoDB practical `.ipynb` file** easily 👇

---

# 🚀 Quick Fix (2 mins method)

Since the file generation failed, you can **create it yourself in Jupyter/Colab** like this:

## 🔹 Step 1: Open Google Colab or Jupyter

---

## 🔹 Step 2: Add these cells

### 🟣 Cell 1 (Markdown)

```
# MongoDB Practical

Name: TANVI ASHOK KADGE
Roll No: SCS2425037

## Aim
Perform CRUD operations and MapReduce in MongoDB
```

---

### 🟣 Cell 2 (Markdown)

```
## Create Database
```

### 🟣 Cell 3 (Code)

```js
use Institution
```

---

### 🟣 Cell 4 (Markdown)

```
## Insert Staff Data
```

### 🟣 Cell 5 (Code)

```js
db.Staff.insertMany([
 {empid:1, empname:"Tanvi", salary:40000, designation:"Clerk"},
 {empid:2, empname:"Manager", salary:60000, designation:"Manager"}
])
```

---

### 🟣 Cell 6 (Code)

```js
db.Staff.find({})
```

---

### 🟣 Cell 7 (Code)

```js
db.Staff.find({}, {empid:1, designation:1, _id:0})
```

---

### 🟣 Cell 8 (Code)

```js
db.Staff.find().sort({salary:-1})
```

---

### 🟣 Cell 9 (Code)

```js
db.Staff.find({
 $or:[
  {designation:"Manager"},
  {salary:{$gt:50000}}
 ]
})
```

---

### 🟣 Cell 10 (Code)

```js
db.Staff.updateMany(
 {designation:"Accountant"},
 {$set:{salary:45000}}
)
```

---

### 🟣 Cell 11 (Code)

```js
db.Staff.deleteMany({salary:{$gt:100000}})
```

---

### 🟣 Cell 12 (Markdown)

```
## MapReduce
```

### 🟣 Cell 13 (Code)

```js
var mapFunction = function(){
 emit(this.product, this.amount);
}

var reduceFunction = function(key, values){
 return Array.sum(values);
}

db.sales.mapReduce(mapFunction, reduceFunction, {out:"TotalSales"})
db.TotalSales.find()
```

---

### 🟣 Cell 14 (Markdown)

```
## Conclusion
Performed CRUD operations and MapReduce successfully.
```

---

# 💡 Pro Tip

👉 After creating:

* Click **File → Download → .ipynb**
* Upload to GitHub

---

# 🚀 Want easier?

I can:
✅ Retry and generate download file again
✅ Merge MongoDB with your other practicals
✅ Make it **perfect journal format with explanations**

Just say: **“retry file”** 👍
